# %% [markdown]
# # HCS Workshop 4: Data Science
#
# Welcome to the data science workshop!

# %% [markdown]
# ## Part 1: Imports
#
# We'll be using `pandas` for data storage and cleaning, along with `altair` and `seaborn` for exploratory visualization.

# %%
# !unzip facebook-jonathanluo1276.zip
# Out:
# Archive:  facebook-jonathanluo1276.zip
#    creating: messages/
#   inflating: messages/autofill_information.json
#   inflating: messages/secret_conversations.json
#   inflating: messages/secret_groups.json
#    creating: messages/inbox/
#    creating: messages/inbox/lrjftp0eua/
#   inflating: messages/inbox/lrjftp0eua/message_1.json
#    creating: messages/inbox/yyuuubwffw/
#   inflating: messages/inbox/yyuuubwffw/message_1.json
#    creating: messages/inbox/190061_ic3lcvzz6w/
#   inflating: messages/inbox/190061_ic3lcvzz6w/message_1.json
#    creating: messages/inbox/190061_ic3lcvzz6w/photos/
#    creating: messages/inbox/190061_ic3lcvzz6w/files/
#    creating: messages/inbox/190061_ic3lcvzz6w/gifs/
#    creating: messages/inbox/190061_ic3lcvzz6w/videos/
#    creating: messages/inbox/6006gang_gjitybvh7g/
#   inflating: messages/inbox/6006gang_gjitybvh7g/message_1.json
#    creating: messages/inbox/6006gang_gjitybvh7g/files/
#    creating: messages/inbox/6006gang_gjitybvh7g/photos/
#    creating: messages/inbox/alxin_4ikfplt7ag/
#   inflating: messages/inbox/alxin_4ikfplt7ag/message_1.json
#    creating: messages/inbox/alexjeronimo__rjgtw5yga/
#   inflating: messages/inbox/alexjeronimo__rjgtw5yga/message_1.json
#    creating: messages/inbox/andrewzhang_zvzqa0r08g/
#   inflating: messages/inbox/andrewzhang_zvzqa0r08g/message_1.json
#    creating: messages/inbox/annettewongtoi_1r9mafxejq/
#   inflating: messages/inbox/annettewongtoi_1r9mafxejq/message_1.json
#    creating: messages/inbox/arjunprasad_bdgbnkbhgw/
#   inflating: messages/inbox/arjunprasad_bdgbnkbhgw/message_1.json
#    creating: messages/inbox/armansaghafi_gdkiqstxfq/
#   inflating: messages/inbox/armansaghafi_gdkiqstxfq/message_1.json
#    creating: messages/inbox/arnavsrivastava_-zdtt3fx7w/
#   inflating: messages/inbox/arnavsrivastava_-zdtt3fx7w/message_1.json
#    creating: messages/inbox/ashernoel_rdqlehgaaq/
#   inflating: messages/inbox/ashernoel_rdqlehgaaq/message_1.json
#    creating: messages/inbox/ashleyzhuang_vh6nqyi21a/
#   inflating: messages/inbox/ashleyzhuang_vh6nqyi21a/message_1.json
#    creating: messages/inbox/betsyding_qgreaqe9hq/
#   inflating: messages/inbox/betsyding_qgreaqe9hq/message_1.json
#    creating: messages/inbox/brandonchen_hdfevkxu3w/
#   inflating: messages/inbox/brandonchen_hdfevkxu3w/message_1.json
#    creating: messages/inbox/carahiggins_uvhj0g7k9w/
#   inflating: messages/inbox/carahiggins_uvhj0g7k9w/message_1.json
#    creating: messages/inbox/carolinagonzalez_15hiuf2yva/
#   inflating: messages/inbox/carolinagonzalez_15hiuf2yva/message_1.json
#    creating: messages/inbox/clarasoares_l5w2coenvw/
#   inflating: messages/inbox/clarasoares_l5w2coenvw/message_1.json
#    creating: messages/inbox/cynthiacolinjulieannaand3others_djbsixwdtq/
#   inflating: messages/inbox/cynthiacolinjulieannaand3others_djbsixwdtq/message_1.json
#    creating: messages/inbox/daniellenam_m0y862ipfg/
#   inflating: messages/inbox/daniellenam_m0y862ipfg/message_1.json
#    creating: messages/inbox/davidzhang_usotuebl0q/
#   inflating: messages/inbox/davidzhang_usotuebl0q/message_1.json
#    creating: messages/inbox/davidzhang_usotuebl0q/photos/
#    creating: messages/inbox/derrickchen_jdqhpwfjcq/
#   inflating: messages/inbox/derrickchen_jdqhpwfjcq/message_1.json
#    creating: messages/inbox/diegocachay_qpv2l2fxqw/
#   inflating: messages/inbox/diegocachay_qpv2l2fxqw/message_1.json
#    creating: messages/inbox/elaineholliman_r_vrgdczsq/
#   inflating: messages/inbox/elaineholliman_r_vrgdczsq/message_1.json
#    creating: messages/inbox/elizascharfstein_fr2xjf93jg/
#   inflating: messages/inbox/elizascharfstein_fr2xjf93jg/message_1.json
#    creating: messages/inbox/emilylu_1f-yctk-ww/
#   inflating: messages/inbox/emilylu_1f-yctk-ww/message_1.json
#    creating: messages/inbox/etonshon_d4aru1frzw/
#   inflating: messages/inbox/etonshon_d4aru1frzw/message_1.json
#    creating: messages/inbox/evangreen_qhfimot4ug/
#   inflating: messages/inbox/evangreen_qhfimot4ug/message_1.json
#    creating: messages/inbox/harrisonoldershaw_39zsex67qa/
#   inflating: messages/inbox/harrisonoldershaw_39zsex67qa/message_1.json
#    creating: messages/inbox/heibahshaikh_zxksrujodg/
#   inflating: messages/inbox/heibahshaikh_zxksrujodg/message_1.json
#    creating: messages/inbox/henrycohen_fo5s6_swwg/
#   inflating: messages/inbox/henrycohen_fo5s6_swwg/message_1.json
#    creating: messages/inbox/isaaczalkin_clhbk9400g/
#   inflating: messages/inbox/isaaczalkin_clhbk9400g/message_1.json
#    creating: messages/inbox/jakobseidner_m1mnqctn1w/
#   inflating: messages/inbox/jakobseidner_m1mnqctn1w/message_1.json
#    creating: messages/inbox/jamaicakalika_fjmawqnsla/
#   inflating: messages/inbox/jamaicakalika_fjmawqnsla/message_1.json
#    creating: messages/inbox/jamesattreejames_cv8clwkk8a/
#   inflating: messages/inbox/jamesattreejames_cv8clwkk8a/message_1.json
#    creating: messages/inbox/janellelee_ofy_oghiea/
#   inflating: messages/inbox/janellelee_ofy_oghiea/message_1.json
#    creating: messages/inbox/jasminechan_xaqdc6hobq/
#   inflating: messages/inbox/jasminechan_xaqdc6hobq/message_1.json
#    creating: messages/inbox/jasonliu_ko7b0cpdza/
#   inflating: messages/inbox/jasonliu_ko7b0cpdza/message_1.json
#    creating: messages/inbox/jeffreychiu_9hybtes4-a/
#   inflating: messages/inbox/jeffreychiu_9hybtes4-a/message_1.json
#    creating: messages/inbox/jeffreyshi_zrt8p1fjtg/
#   inflating: messages/inbox/jeffreyshi_zrt8p1fjtg/message_1.json
#    creating: messages/inbox/jenniferguo_cl7ynpafuw/
#   inflating: messages/inbox/jenniferguo_cl7ynpafuw/message_1.json
#    creating: messages/inbox/jerrywu_7uodfd85oq/
#   inflating: messages/inbox/jerrywu_7uodfd85oq/message_1.json
#    creating: messages/inbox/jialiangjiang_ngsyziua2a/
#   inflating: messages/inbox/jialiangjiang_ngsyziua2a/message_1.json
#    creating: messages/inbox/josephhartono_xllrvp_bna/
#   inflating: messages/inbox/josephhartono_xllrvp_bna/message_1.json
#    creating: messages/inbox/katherinetian_vp3p1tmfvq/
#   inflating: messages/inbox/katherinetian_vp3p1tmfvq/message_1.json
#    creating: messages/inbox/kevinlee_fo-1ndrbow/
#   inflating: messages/inbox/kevinlee_fo-1ndrbow/message_1.json
#    creating: messages/inbox/kevinsu_yurkrwdtuq/
#   inflating: messages/inbox/kevinsu_yurkrwdtuq/message_1.json
#    creating: messages/inbox/kevinsu_yurkrwdtuq/files/
#    creating: messages/inbox/kevinsu_yurkrwdtuq/photos/
#    creating: messages/inbox/koryswygert_ibb6xntcja/
#   inflating: messages/inbox/koryswygert_ibb6xntcja/message_1.json
#    creating: messages/inbox/lilyli_hghrvhrhmq/
#   inflating: messages/inbox/lilyli_hghrvhrhmq/message_1.json
#    creating: messages/inbox/lilysuennen_nvnsxcm2mg/
#   inflating: messages/inbox/lilysuennen_nvnsxcm2mg/message_1.json
#    creating: messages/inbox/linzhu_f-uqddmv6w/
#   inflating: messages/inbox/linzhu_f-uqddmv6w/message_1.json
#    creating: messages/inbox/linzhu_f-uqddmv6w/photos/
#    creating: messages/inbox/maddychen_iiuunxpyuq/
#   inflating: messages/inbox/maddychen_iiuunxpyuq/message_1.json
#    creating: messages/inbox/mariafedyk_wiyejxfgkw/
#   inflating: messages/inbox/mariafedyk_wiyejxfgkw/message_1.json
#    creating: messages/inbox/michellelee_entbyah6rg/
#   inflating: messages/inbox/michellelee_entbyah6rg/message_1.json
#    creating: messages/inbox/milosiegmannwatson_1e6vd6yrwq/
#   inflating: messages/inbox/milosiegmannwatson_1e6vd6yrwq/message_1.json
#    creating: messages/inbox/mishaelhibshoosh_wkftki9ddw/
#   inflating: messages/inbox/mishaelhibshoosh_wkftki9ddw/message_1.json
#    creating: messages/inbox/nataliaporras_ky1uzjourw/
#   inflating: messages/inbox/nataliaporras_ky1uzjourw/message_1.json
#    creating: messages/inbox/nicholaschen_mn66slyswq/
#   inflating: messages/inbox/nicholaschen_mn66slyswq/message_1.json
#    creating: messages/inbox/nicolechen_b0xgv5dlwa/
#   inflating: messages/inbox/nicolechen_b0xgv5dlwa/message_1.json
#    creating: messages/inbox/nikhildharmaraj_vtekw5acow/
#   inflating: messages/inbox/nikhildharmaraj_vtekw5acow/message_1.json
#    creating: messages/inbox/pallaschou_2wxib-w7ta/
#   inflating: messages/inbox/pallaschou_2wxib-w7ta/message_1.json
#    creating: messages/inbox/peiwenxiao_brhcof2uhw/
#   inflating: messages/inbox/peiwenxiao_brhcof2uhw/message_1.json
#    creating: messages/inbox/philiplee_kc6pqrl4lg/
#   inflating: messages/inbox/philiplee_kc6pqrl4lg/message_1.json
#    creating: messages/inbox/raquelramirez_gmp-rh9slw/
#   inflating: messages/inbox/raquelramirez_gmp-rh9slw/message_1.json
#    creating: messages/inbox/raymondqin_ohu09bqj8q/
#   inflating: messages/inbox/raymondqin_ohu09bqj8q/message_1.json
#    creating: messages/inbox/ronnamin_t28ytsu0jg/
#   inflating: messages/inbox/ronnamin_t28ytsu0jg/message_1.json
#    creating: messages/inbox/rosehong_a0emjjdcma/
#   inflating: messages/inbox/rosehong_a0emjjdcma/message_1.json
#    creating: messages/inbox/rosehong_a0emjjdcma/photos/
#    creating: messages/inbox/ryanlian_7x8xz3wisw/
#   inflating: messages/inbox/ryanlian_7x8xz3wisw/message_1.json
#    creating: messages/inbox/sarahweber_pttue1tg4w/
#   inflating: messages/inbox/sarahweber_pttue1tg4w/message_1.json
#    creating: messages/inbox/serenaingalls_l4tnelqfpg/
#   inflating: messages/inbox/serenaingalls_l4tnelqfpg/message_1.json
#    creating: messages/inbox/shaineelim_qdobd7jpsw/
#   inflating: messages/inbox/shaineelim_qdobd7jpsw/message_1.json
#    creating: messages/inbox/shosholeighaho_wf6j1hmkea/
#   inflating: messages/inbox/shosholeighaho_wf6j1hmkea/message_1.json
#    creating: messages/inbox/simonyong_dagkenejcq/
#   inflating: messages/inbox/simonyong_dagkenejcq/message_1.json
#    creating: messages/inbox/stelladixon_kwetj3vzyg/
#   inflating: messages/inbox/stelladixon_kwetj3vzyg/message_1.json
#    creating: messages/inbox/tessmcginley_wfkolyfpqa/
#   inflating: messages/inbox/tessmcginley_wfkolyfpqa/message_1.json
#    creating: messages/inbox/trevorryan_e1o5tq5roa/
#   inflating: messages/inbox/trevorryan_e1o5tq5roa/message_1.json
#    creating: messages/inbox/winstonluo_qryorvvtgw/
#   inflating: messages/inbox/winstonluo_qryorvvtgw/message_1.json
#    creating: messages/inbox/yaraeliyan_stj8gmx_6q/
#   inflating: messages/inbox/yaraeliyan_stj8gmx_6q/message_1.json
#    creating: messages/inbox/wangjinduo_0mq8c1clwq/
#   inflating: messages/inbox/wangjinduo_0mq8c1clwq/message_1.json
#    creating: messages/message_requests/
#    creating: messages/message_requests/kevinstephen_f7d0mbrdma/
#   inflating: messages/message_requests/kevinstephen_f7d0mbrdma/message_1.json
#    creating: messages/stickers_used/
#   inflating: messages/stickers_used/39178562_1505197616293642_5411344281094848512_n_369239263222822.png
#  extracting: messages/stickers_used/851587_369239346556147_162929011_n_369239343222814.png
#   inflating: messages/stickers_used/36873503_237318547087805_6018490268330754048_n_237318537087806.png
#   inflating: messages/stickers_used/10574684_823242091028102_1185278483_n_823242087694769.png
#   inflating: messages/inbox/6006gang_gjitybvh7g/photos/120253788_1070413200043200_1840698322694372562_n_1070413196709867.png
#   inflating: messages/inbox/rosehong_a0emjjdcma/photos/274074681_494963052143498_6264308717965652017_n_494963045476832.png
#   inflating: messages/inbox/rosehong_a0emjjdcma/photos/272781513_3399940836899868_1054018840221845307_n_3399940833566535.png
#   inflating: messages/inbox/rosehong_a0emjjdcma/photos/278255035_4765851796845574_8002591758396178346_n_4765851793512241.png
#   inflating: messages/inbox/rosehong_a0emjjdcma/photos/277912061_356239813224305_6702018492519144175_n_356239806557639.jpg
#   inflating: messages/inbox/davidzhang_usotuebl0q/photos/119642799_324583818776594_2777982655204623086_n_2446339212157952.png
#   inflating: messages/inbox/linzhu_f-uqddmv6w/photos/70227202_510216966401954_3206693600477839360_n_510216963068621.png

# %%
import json
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import altair as alt
from altair import datum, expr

alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ## Part 2: Loading Data
#
# The cell below will load your Facebook messages data into a table called `df`. Each row of this table corresponds to a single message, and it has four columns:
#
# - `chat`: The ID of the messenger chat that this message was sent in.
# - `sender`: The name of the user who sent the message.
# - `time`: A timestamp specifying exactly when the message was sent.
# - `content`: The text of the message.
#
# The `build_dataframe()` function loads all of this data in files downloaded from Facebook. It takes one argument, `path`, containing the folder where the unzipped data resides. If you're running this notebook in the same directory as `messages` then no need to change anything; otherwise, please specify the path to your `messages` folder as an argument to the function.

# %%
def build_dataframe(path='messages'):
    rows_list = []
    for filename in Path(path).glob('inbox/*/message_*.json'):
        chat = filename.parent.name
        with open(filename, 'r') as f:
            obj = json.load(f)
        for entry in obj['messages']:
            if entry['type'] == 'Generic' and entry.get('content') is not None:
                rows_list.append({
                    'chat': chat,
                    'sender': entry['sender_name'],
                    'time': pd.to_datetime(entry['timestamp_ms'], unit='ms'),
                    'content': entry['content'],
                })
    return pd.DataFrame(rows_list)

df = build_dataframe()

# %% [markdown]
# Let's quickly check to make sure that our data was loaded properly.

# %%
df
# Out:
#                            chat           sender                    time  \
# 0        jasminechan_xaqdc6hobq     Jasmine Chan 2019-11-24 05:37:54.000
# 1       tessmcginley_wfkolyfpqa     Jonathan Luo 2019-08-06 04:24:55.301
# 2         davidzhang_usotuebl0q      David Zhang 2022-04-18 22:26:00.518
# 3         davidzhang_usotuebl0q     Jonathan Luo 2022-04-17 23:35:32.723
# 4         davidzhang_usotuebl0q      David Zhang 2022-04-17 01:45:24.134
# ...                         ...              ...                     ...
# 2471  elaineholliman_r_vrgdczsq  Elaine Holliman 2019-08-28 11:26:18.599
# 2472     carahiggins_uvhj0g7k9w     Cara Higgins 2019-08-25 14:04:06.980
# 2473      janellelee_ofy_oghiea      Janelle Lee 2019-08-03 04:30:17.532
# 2474      shaineelim_qdobd7jpsw      Shainee Lim 2019-10-24 18:16:28.945
# 2475   josephhartono_xllrvp_bna     Jonathan Luo 2020-01-23 07:28:17.959
#
#                                  content
# 0     You are now connected on Messenger
# 1     You are now connected on Messenger
# 2                        no worries man!
# 3                               Thx man!
# 4                      her name is Erika
# ...                                  ...
# 2471  You are now connected on Messenger
# 2472  You are now connected on Messenger
# 2473  You are now connected on Messenger
# 2474  You are now connected on Messenger
# 2475  You are now connected on Messenger
#
# [2476 rows x 4 columns]

# %%
df.chat.value_counts()
# Out:
# 190061_ic3lcvzz6w                             1430
# 6006gang_gjitybvh7g                            568
# rosehong_a0emjjdcma                            147
# cynthiacolinjulieannaand3others_djbsixwdtq     128
# davidzhang_usotuebl0q                           87
#                                               ...
# milosiegmannwatson_1e6vd6yrwq                    1
# tessmcginley_wfkolyfpqa                          1
# daniellenam_m0y862ipfg                           1
# maddychen_iiuunxpyuq                             1
# josephhartono_xllrvp_bna                         1
# Name: chat, Length: 79, dtype: int64

# %% [markdown]
# ## Part 3: Data Visualization
#
# Now we can start exploring! First, how many messages have we sent over time?

# %%
alt.Chart(df).mark_line().encode(
    x='yearmonth(time):T',
    y='count()',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Let's color-code this graph by conversation. We can add tooltips and a title along the way.

# %%
alt.Chart(df).mark_bar().encode(
    x='monthdate(time):T',
    y='count()',
    color='chat:N',
    tooltip=['chat', 'count()'],
).properties(
    title='Number of Facebook Messages',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# How about the number of messages sent by each participant in a particular chat?

# %% [markdown]
# Which participants tend to send the most messages in each of your conversations, if any?

# %%
chat_id = '190061_ic3lcvzz6w'

alt.Chart(df.query(f'chat == "{chat_id}"')).mark_bar().encode(
    color='sender:N',
    x='yearmonth(time):T',
    y='count()',
    tooltip=['sender', 'count()'],
).properties(
    title='Facebook Messages in Group Chat',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    alt.X('count()', stack='normalize', title='frequency'),
    alt.Y('chat'),
    alt.Color('sender'),
    tooltip=['sender', alt.Tooltip('count()', title='messages')],
).properties(
    title='Who Dominates the Conversation?',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Finally, let's look at the number of messages (and words) you sent on each day of the year.

# %%
sender = 'Jonathan Luo'

alt.Chart(df).mark_rect().encode(
    alt.X('date(time):O', title='day'),
    alt.Y('yearmonth(time):O', title='month'),
    alt.Color('count()', scale=alt.Scale(type='linear')),
    tooltip=[
        alt.Tooltip('count()', title='Messages'),
        alt.Tooltip('sum(words):Q', title='Words'),
    ],
).transform_filter(
    datum.sender == sender,
).transform_calculate(
    words=expr.length(expr.split(datum.content, ' ')),
).properties(
    title='Number of Messages Sent by Day',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Part 4: Exercises
#
# Create two more data visualizations, different from the ones above. What are you curious to learn about? Some suggestions:
#
# - Change some of the chart types to line graphs or scatter plots, or experiment with [scales](https://vega.github.io/vega/docs/scales/) and [color schemes](https://vega.github.io/vega/docs/schemes/).
# - On which hours and days of the week are you most active?
# - Has the average length of your messages, increased, decreased, or stayed the same over time?
# - Filter your messages by a particular word. Who do you talk to most about, e.g., sports?
# - Who sends you the most messages with [positive sentiment](https://www.nltk.org/api/nltk.sentiment.html)? Has this changed over time?
#
# If you're looking for more inspiration, check out the [Altair example gallery](https://altair-viz.github.io/gallery/index.html)!

# %%
# Viz 1: Interactive Histogram of Time of Day Messages were Sent into the Group Chat "19.0061"
# (Click and drag on bottom panel to see bins change on top panel)

chat_id = '190061_ic3lcvzz6w'
chat_name = '19.0061'

source = df.query(f'chat == "{chat_id}"')
brush = alt.selection_interval(encodings=['x'])

base = alt.Chart(source).transform_calculate(
    time="((hours(datum.time) + minutes(datum.time) / 60) + 20) % 24"  # Converting GMT to EDT
).mark_bar().encode(
    y='count():Q',
    color=alt.Color('count()', scale=alt.Scale(type='linear')),
    tooltip=[
        alt.Tooltip('count()', title='Messages'),
    ],
).properties(
    width=600,
    height=100,
    title=f'Time of Day at which Messages Were Sent into Chat "{chat_name}"',
)

x_axis_label = "Hour of Day (EDT)"

alt.vconcat(
  base.encode(
    alt.X('time:Q',
      bin=alt.Bin(maxbins=30, extent=brush),
      scale=alt.Scale(domain=brush),
      title=x_axis_label,
    )
  ),
  base.encode(
    alt.X('time:Q',
          bin=alt.Bin(maxbins=30),
          title=x_axis_label,
          )
  ).add_selection(brush)
)
# Out:
# alt.VConcatChart(...)

# %%
# Viz 2: Visualization of the Mean Number of Words per Message sent by Me
# Appears that aside from really popping off on Sept 8, 2020, I've been staying
# pretty consistent in terms of my message lengths (getting slightly longer in
# the last year though)

sender = 'Jonathan Luo'

alt.Chart(df).mark_rect().encode(
    alt.X('date(time):O', title='Day'),
    alt.Y('yearmonth(time):O', title='Month'),
    alt.Color('mean(words):Q', scale=alt.Scale(type='linear'), title='Mean Words per Message'),
    tooltip=[
        alt.Tooltip('yearmonthdate(time):O', title='Date'),
        alt.Tooltip('mean(words):Q', title='Mean Words per Message', format='.2f'),
        alt.Tooltip('count()', title='Messages'),
    ],
).transform_filter(
    datum.sender == sender,
).transform_calculate(
    words=expr.length(expr.split(datum.content, ' ')),
).properties(
    title='Mean Number of Words per Message by Day',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Part 5: Submission

# %% [markdown]
# If you're comping HCS and would like to receive credit for completing this workshop, here are the instructions to do so.
#
# 1. Click the Kernel >> "Restart Kernel and Run All Cells" button at the top-left of the screen. This will run your entire notebook from top to bottom, ensuring that your code is reproducible.
# 2. Click on the ellipsis icon at the top-right of your two personal visualizations, and save them as SVG graphics files.
# 3. Click the Kernel >> "Restart Kernel and Clear All Outputs" button at the top-left of the screen. This will remove all outputs from your notebook and leave only the code, which will greatly reduce file size. After this, you're all set!
# 4. Save the notebook, then drag-and-drop your `.ipynb` file to a [GitHub Gist](https://gist.github.com/).
# 5. Submit at the [Google Form](https://forms.gle/ssjtbjyGr6qtSL2P9).
#
# Congratulations for finishing!
